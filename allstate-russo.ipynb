# %% [markdown]
# Michael Russo
#
# 661624457
#
# Project: Introduction to Machine Learning Applications Section 2 Fall 2020
#
# Allstate Kaggle Competition

# %% [markdown]
# Analysis for this code is peformed in the Kaggle online jupiter notebooks enviroment.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/allstate-claims-severity/sample_submission.csv
# /kaggle/input/allstate-claims-severity/train.csv.zip
# /kaggle/input/allstate-claims-severity/sample_submission.csv.zip
# /kaggle/input/allstate-claims-severity/train.csv
# /kaggle/input/allstate-claims-severity/test.csv
# /kaggle/input/allstate-claims-severity/test.csv.zip

# %% [markdown]
# import given Kaggle Test and Train data sets and sample sumbission file three times.

# %%
train_data = pd.read_csv("../input/allstate-claims-severity/train.csv")
test_data = pd.read_csv("../input/allstate-claims-severity/test.csv")
sample_submission = pd.read_csv("../input/allstate-claims-severity/sample_submission.csv")
sample_submission2 = sample_submission
sample_submission3= sample_submission

# %%
print("Train data dimensions: ", train_data.shape)
print("Test data dimensions: ", test_data.shape)
# Out:
# Train data dimensions:  (188318, 132)
# Test data dimensions:  (125546, 131)

# %%
#train_data.drop('id',axis=1,inplace=True)
train_data.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
test_data.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# 0   4    A    B    A    A    A    A    A    A    B  ...  0.281143  0.466591
# 1   6    A    B    A    B    A    A    A    A    B  ...  0.836443  0.482425
# 2   9    A    B    A    B    B    A    B    A    B  ...  0.718531  0.212308
# 3  12    A    A    A    A    B    A    A    A    A  ...  0.397069  0.369930
# 4  15    B    A    A    A    A    B    A    A    A  ...  0.302678  0.398862
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13    cont14
# 0  0.317681  0.61229  0.34365  0.38016  0.377724  0.369858  0.704052  0.392562
# 1  0.443760  0.71330  0.51890  0.60401  0.689039  0.675759  0.453468  0.208045
# 2  0.325779  0.29758  0.34365  0.30529  0.245410  0.241676  0.258586  0.297232
# 3  0.342355  0.40028  0.33237  0.31480  0.348867  0.341872  0.592264  0.555955
# 4  0.391833  0.23688  0.43731  0.50556  0.359572  0.352251  0.301535  0.825823
#
# [5 rows x 131 columns]

# %%
table1 = train_data.describe() # describe the value range, standard deviation and averages.
table1
# Out:
#                   id          cont1          cont2          cont3  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean   294135.982561       0.493861       0.507188       0.498918
# std    169336.084867       0.187640       0.207202       0.202105
# min         1.000000       0.000016       0.001149       0.002634
# 25%    147748.250000       0.346090       0.358319       0.336963
# 50%    294539.500000       0.475784       0.555782       0.527991
# 75%    440680.500000       0.623912       0.681761       0.634224
# max    587633.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.491812       0.487428       0.490945       0.484970
# std         0.211292       0.209027       0.205273       0.178450
# min         0.176921       0.281143       0.012683       0.069503
# 25%         0.327354       0.281143       0.336105       0.350175
# 50%         0.452887       0.422268       0.440945       0.438285
# 75%         0.652072       0.643315       0.655021       0.591045
# max         0.954297       0.983674       0.997162       1.000000
#
#                cont8          cont9         cont10         cont11  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.486437       0.485506       0.498066       0.493511
# std         0.199370       0.181660       0.185877       0.209737
# min         0.236880       0.000080       0.000000       0.035321
# 25%         0.312800       0.358970       0.364580       0.310961
# 50%         0.441060       0.441450       0.461190       0.457203
# 75%         0.623580       0.566820       0.614590       0.678924
# max         0.980200       0.995400       0.994980       0.998742
#
#               cont12         cont13         cont14           loss
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.493150       0.493138       0.495717    3037.337686
# std         0.209427       0.212777       0.222488    2904.086186
# min         0.036232       0.000228       0.179722       0.670000
# 25%         0.311661       0.315758       0.294610    1204.460000
# 50%         0.462286       0.363547       0.407403    2115.570000
# 75%         0.675759       0.689974       0.724623    3864.045000
# max         0.998484       0.988494       0.844848  121012.250000

# %%
#table1.to_csv('calls.csv') # export for report

# %%
#train_data.skew()

# %% [markdown]
# Select continious features for analysis

# %%
contFeatureslist = [] # to investigate continuous data features, matrix with just continuous varaibel columns and loss 
for colName,x in train_data.iloc[1,:].iteritems():
    if(not str(x).isalpha()):
        contFeatureslist.append(colName)

print(contFeatureslist)

#contFeatureslist = ['id', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14', 'loss']
# Out:
# ['id', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14', 'loss']

# %%
contFeatureslist.remove("id")
contFeatureslist.remove("loss")

# %%
train_data_simple=train_data[contFeatureslist] # investigate continous data 
#data=pd.melt(df))
train_data_simple.head()
# Out:
#       cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0  0.726300  0.245921  0.187583  0.789639  0.310061  0.718367  0.335060
# 1  0.330514  0.737068  0.592681  0.614134  0.885834  0.438917  0.436585
# 2  0.261841  0.358319  0.484196  0.236924  0.397069  0.289648  0.315545
# 3  0.321594  0.555782  0.527991  0.373816  0.422268  0.440945  0.391128
# 4  0.273204  0.159990  0.527991  0.473202  0.704268  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(13,9)) # plot contious data as box plots to investigate skew, avarage, and range
sns.boxplot(x="variable", y="value", data=pd.melt(train_data_simple))


plt.figure(figsize=(13,9)) # plot contious data as violin plots to better investigate skew, avarage, and range
sns.violinplot(x="variable", y="value", data=pd.melt(train_data_simple))

# %%
train_data[contFeatureslist].hist(bins=50, figsize=(16,12)) # further investigate distribution of continous data
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f92dac08e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92dd6c2d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92dd700ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92dacee8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f92dac80510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92e4b22a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d93bdcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92dd6fb2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f92dd6fb310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d938ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d93036d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d92b9d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f92d927d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d9233a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d91f4150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f92d92297d0>]],
#       dtype=object)

# %%
contFeatureslist.append("loss")

correlationMatrix = train_data[contFeatureslist].corr().abs() # investigate continous data coorelation between varables

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
s = correlationMatrix.unstack()  # list continuous varibles with most correlation

so = s.sort_values(kind="quicksort",ascending=False)

print("Top 5 most correlated continuous feature pairs: \n")
print(so[so != 1.0][0:10])
# Out:
# Top 5 most correlated continuous feature pairs:
#
# cont12  cont11    0.994384
# cont11  cont12    0.994384
# cont1   cont9     0.929912
# cont9   cont1     0.929912
# cont6   cont10    0.883351
# cont10  cont6     0.883351
# cont13  cont6     0.815091
# cont6   cont13    0.815091
# cont1   cont10    0.808551
# cont10  cont1     0.808551
# dtype: float64

# %% [markdown]
# Now that we have the top 5 most correlated continuous feature pairs, we can look to remove features if needed.

# %%
plt.figure(figsize=(13,9)) # investigate loss dependent variable - seen that skew is high and positive
#sns.distplot(train_data["loss"])
sns.boxplot(train_data["loss"])

# %% [markdown]
# Here, we can see loss is highly right skewed data. This happened because there are many outliers in the data that we can see from box plot.
#
# logarithm on loss function Log(1+x) - This mathematical function helps user to calculate natural logarithmic value of x+1 where x belongs to all the input array elements.
# It is used to get a normal distribution so that we can train model using target feature as log of loss. This way we don't have to remove outliers and algorithems can predict better.
#
# Figure below shows skew correction.

# %%
train_data["logloss"] = np.log1p(train_data["loss"]) # normalize the loss dependent varable so that model can predict better

# %%
plt.figure(figsize=(13,9)) #Plot shows that skew is corrected to a large extent
#sns.distplot(np.log1p(train_data["loss"]))
sns.boxplot(train_data["logloss"])

# %% [markdown]
# Next we analize the Catagorial columns, Select Catagorial features for analysis with similar method as above

# %%
catCount = sum(str(x).isalpha() for x in train_data.iloc[1,:]) # count number of catagorial varables
print("Number of categories: ",catCount)
# Out:
# Number of categories:  116

# %%
catFeatureslist = [] # to investigate catagorial data features, matrix with just ccatagorial varaibel columns and loss 
for colName,x in train_data.iloc[1,:].iteritems():
    if(str(x).isalpha()):
        catFeatureslist.append(colName)
        
#catFeatureslist

# %%
print(train_data[catFeatureslist].apply(pd.Series.nunique)) # shows the numeber of unique catagorial values for each catagorial variables
# Out:
# cat1        2
# cat2        2
# cat3        2
# cat4        2
# cat5        2
#          ...
# cat112     51
# cat113     61
# cat114     19
# cat115     23
# cat116    326
# Length: 116, dtype: int64

# %% [markdown]
# sklearn.preprocessing import LabelEncoder is used to transform non-numerical labels to numerical labels so that model can incorperate them.

# %%
from sklearn.preprocessing import LabelEncoder # trasform non-numerical labels to numerical labels so that model can incorperate them.
for cf1 in catFeatureslist:
    le = LabelEncoder()
    le.fit(train_data[cf1].unique())
    train_data[cf1] = le.transform(train_data[cf1])
    le.fit(test_data[cf1].unique())
    test_data[cf1] = le.transform(test_data[cf1])

# %%
train_data.head() # view test data with new labels
# Out:
#    id  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont7  \
# 0   1     0     1     0     1     0     0     0     0     1  ...  0.335060
# 1   2     0     1     0     0     0     0     0     0     1  ...  0.436585
# 2   5     0     1     0     0     1     0     0     0     1  ...  0.315545
# 3  10     1     1     0     1     0     0     0     0     1  ...  0.391128
# 4  11     0     1     0     1     0     0     0     0     1  ...  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss  \
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
#     logloss
# 0  7.702637
# 1  7.158203
# 2  8.008396
# 3  6.846784
# 4  7.924742
#
# [5 rows x 133 columns]

# %%
filter2 = list((train_data[catFeatureslist].apply(pd.Series.nunique) == 2)) # print Top 5 most correlated categorical feature pairs
catFeatures2List = [i for (i, v) in zip(catFeatureslist, filter2) if v]
catFeatures2List.append("loss")

corrCatMatrix = train_data[catFeatures2List].corr().abs()

s = corrCatMatrix.unstack()
so2= s.sort_values(kind="quicksort",ascending=False)

print("Top 5 most correlated categorical feature pairs: \n")
print(so2[so2 != 1.0][0:10])
# Out:
# Top 5 most correlated categorical feature pairs:
#
# cat2   cat9     0.932420
# cat9   cat2     0.932420
# cat50  cat6     0.925731
# cat6   cat50    0.925731
# cat8   cat66    0.862231
# cat66  cat8     0.862231
# cat57  cat7     0.809418
# cat7   cat57    0.809418
# cat3   cat16    0.783480
# cat16  cat3     0.783480
# dtype: float64

# %% [markdown]
# Now that we have the top 5 most correlated categorical feature pairs, we can look to remove features if needed.

# %% [markdown]
# ****Build Model****
#
# Three models will be investigated CatBoost , XGBoost, and LightGBM.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %% [markdown]
# Build Model Featuring LightGBM algorithm

# %%
X = train_data.drop(['loss',"logloss"], axis=1)
y = train_data["logloss"]

# %%
X_train,X_val,y_train, y_val = train_test_split(X,y,test_size=0.1)

# %%
LGBMR = LGBMRegressor(n_estimators=300, learning_rate=0.1, random_state=123)
LGBMR.fit(X_train,y_train)
LGBMRpred = LGBMR.predict(X_val)

print(mean_absolute_error(LGBMRpred,y_val))
# Out:
# 0.4135477083669933

# %%
LGBMR_feature_imp = pd.DataFrame(sorted(zip(LGBMR.feature_importances_,X.columns)), columns=['Value','Feature'])

fig,ax = plt.subplots(1,1,figsize=(20,30))
sns.barplot(x="Value", y="Feature", data=LGBMR_feature_imp.sort_values(by="Value", ascending=False), ax=ax)
plt.title('LightGBM Features Importance')
# Out:
# Text(0.5, 1.0, 'LightGBM Features Importance')

# %%
test_predictions = LGBMR.predict(test_data)

predictions=np.exp(test_predictions)-1
sample_submission['loss']=predictions

LGBMRResult = sample_submission.loc[:, ['id','loss']]

LGBMRResult.to_csv('Result1.csv', index=False)
LGBMRResult.head()
# Out:
#    id         loss
# 0   4  1506.231571
# 1   6  1762.009047
# 2   9  8501.563170
# 3  12  5303.410178
# 4  15   840.420453

# %% [markdown]
# Build Model Featuring XGBoost algorithm

# %%
X = train_data.drop(['loss',"logloss"], axis=1)
y = train_data["logloss"]
X_train,X_val,y_train, y_val = train_test_split(X,y,test_size=0.1)

# %%
XGBR = XGBRegressor(n_estimators=300, learning_rate=0.1, random_state=123)
XGBR.fit(X_train,y_train)
XGBRpred = XGBR.predict(X_val)

print(mean_absolute_error(XGBRpred,y_val))
# Out:
# 0.41581675024865056

# %%
XGBR_feature_imp = pd.DataFrame(sorted(zip(XGBR.feature_importances_,X.columns)), columns=['Value','Feature'])

fig,ax = plt.subplots(1,1,figsize=(20,30))
sns.barplot(x="Value", y="Feature", data=XGBR_feature_imp.sort_values(by="Value", ascending=False), ax=ax)
plt.title('XGBRegressor Features Importance')
# Out:
# Text(0.5, 1.0, 'XGBRegressor Features Importance')

# %%
test_predictions2 = XGBR.predict(test_data)

predictions2=np.exp(test_predictions2)-1
sample_submission2['loss']=predictions2


XGBRResult = sample_submission2.loc[:, ['id','loss']]

XGBRResult.to_csv('Result2.csv', index=False)
XGBRResult.head()
# Out:
#    id         loss
# 0   4  1576.468262
# 1   6  2757.001709
# 2   9  8579.988281
# 3  12  6257.754395
# 4  15   908.660706

# %% [markdown]
# Build Model Featuring Catboost algorithm

# %%
X = train_data.drop(['loss',"logloss"], axis=1)
y = train_data["logloss"]
X_train,X_val,y_train, y_val = train_test_split(X,y,test_size=0.1)

# %%
CatB = CatBoostRegressor(n_estimators=300, learning_rate=0.1, random_state=123)
CatB.fit(X_train,y_train)
CatBpred = CatB.predict(X_val)

print(mean_absolute_error(CatBpred,y_val))
# Out:
# 0:	learn: 0.7827998	total: 109ms	remaining: 32.7s
# 1:	learn: 0.7587727	total: 163ms	remaining: 24.3s
# 2:	learn: 0.7385599	total: 217ms	remaining: 21.4s
# 3:	learn: 0.7208593	total: 270ms	remaining: 20s
# 4:	learn: 0.7052657	total: 320ms	remaining: 18.9s
# 5:	learn: 0.6921417	total: 374ms	remaining: 18.3s
# 6:	learn: 0.6808883	total: 424ms	remaining: 17.8s
# 7:	learn: 0.6703390	total: 471ms	remaining: 17.2s
# 8:	learn: 0.6610733	total: 517ms	remaining: 16.7s
# 9:	learn: 0.6532532	total: 578ms	remaining: 16.8s
# 10:	learn: 0.6457123	total: 627ms	remaining: 16.5s
# 11:	learn: 0.6396958	total: 674ms	remaining: 16.2s
# 12:	learn: 0.6344074	total: 729ms	remaining: 16.1s
# 13:	learn: 0.6296431	total: 780ms	remaining: 15.9s
# 14:	learn: 0.6248305	total: 834ms	remaining: 15.8s
# 15:	learn: 0.6211737	total: 889ms	remaining: 15.8s
# 16:	learn: 0.6175841	total: 944ms	remaining: 15.7s
# 17:	learn: 0.6144341	total: 993ms	remaining: 15.6s
# 18:	learn: 0.6116882	total: 1.04s	remaining: 15.4s
# 19:	learn: 0.6081370	total: 1.09s	remaining: 15.3s
# 20:	learn: 0.6055249	total: 1.13s	remaining: 15s
# 21:	learn: 0.6029000	total: 1.19s	remaining: 15s
# 22:	learn: 0.6007290	total: 1.24s	remaining: 14.9s
# 23:	learn: 0.5983886	total: 1.29s	remaining: 14.8s
# 24:	learn: 0.5960794	total: 1.34s	remaining: 14.7s
# 25:	learn: 0.5942104	total: 1.38s	remaining: 14.6s
# 26:	learn: 0.5922924	total: 1.47s	remaining: 14.8s
# 169:	learn: 0.5437112	total: 8.8s	remaining: 6.73s
# 170:	learn: 0.5435698	total: 8.86s	remaining: 6.69s
# 171:	learn: 0.5434814	total: 8.91s	remaining: 6.63s
# 172:	learn: 0.5434011	total: 8.96s	remaining: 6.57s
# 173:	learn: 0.5433213	total: 9s	remaining: 6.52s
# 174:	learn: 0.5432616	total: 9.04s	remaining: 6.45s
# 175:	learn: 0.5431771	total: 9.08s	remaining: 6.4s
# 176:	learn: 0.5431170	total: 9.13s	remaining: 6.34s
# 177:	learn: 0.5430457	total: 9.18s	remaining: 6.29s
# 178:	learn: 0.5429459	total: 9.22s	remaining: 6.23s
# 179:	learn: 0.5428686	total: 9.27s	remaining: 6.18s
# 180:	learn: 0.5427936	total: 9.32s	remaining: 6.13s
# 181:	learn: 0.5426970	total: 9.37s	remaining: 6.08s
# 182:	learn: 0.5426042	total: 9.42s	remaining: 6.02s
# 183:	learn: 0.5425197	total: 9.47s	remaining: 5.97s
# 184:	learn: 0.5424684	total: 9.51s	remaining: 5.91s
# 185:	learn: 0.5424310	total: 9.55s	remaining: 5.85s
# 186:	learn: 0.5423635	total: 9.6s	remaining: 5.8s
# 187:	learn: 0.5423118	total: 9.63s	remaining: 5.74s
# 188:	learn: 0.5422243	total: 9.68s	remaining: 5.69s
# 189:	learn: 0.5421503	total: 9.74s	remaining: 5.64s
# 190:	learn: 0.5420279	total: 9.79s	remaining: 5.59s
# 191:	learn: 0.5419645	total: 9.83s	remaining: 5.53s
# 192:	learn: 0.5418903	total: 9.88s	remaining: 5.48s
# 193:	learn: 0.5418278	total: 9.92s	remaining: 5.42s
# 194:	learn: 0.5417559	total: 9.97s	remaining: 5.37s
# 195:	learn: 0.5416954	total: 10s	remaining: 5.31s
# 196:	learn: 0.5416185	total: 10.1s	remaining: 5.26s
# 197:	learn: 0.5414971	total: 10.1s	remaining: 5.21s
# 198:	learn: 0.5414458	total: 10.2s	remaining: 5.16s
# 199:	learn: 0.5413626	total: 10.2s	remaining: 5.1s
# 200:	learn: 0.5412845	total: 10.3s	remaining: 5.05s
# 201:	learn: 0.5412023	total: 10.3s	remaining: 5s
# 202:	learn: 0.5411258	total: 10.4s	remaining: 4.95s
# 203:	learn: 0.5410682	total: 10.4s	remaining: 4.9s
# 204:	learn: 0.5409861	total: 10.5s	remaining: 4.84s
# 205:	learn: 0.5409277	total: 10.5s	remaining: 4.79s
# 206:	learn: 0.5408568	total: 10.5s	remaining: 4.74s
# 207:	learn: 0.5407908	total: 10.6s	remaining: 4.68s
# 208:	learn: 0.5407248	total: 10.6s	remaining: 4.63s
# 209:	learn: 0.5406628	total: 10.7s	remaining: 4.58s
# 210:	learn: 0.5405786	total: 10.7s	remaining: 4.53s
# 211:	learn: 0.5405204	total: 10.8s	remaining: 4.48s
# 212:	learn: 0.5404552	total: 10.8s	remaining: 4.43s
# 213:	learn: 0.5404128	total: 10.9s	remaining: 4.37s
# 214:	learn: 0.5403345	total: 10.9s	remaining: 4.32s
# 215:	learn: 0.5402915	total: 11s	remaining: 4.27s
# 216:	learn: 0.5401884	total: 11s	remaining: 4.22s
# 217:	learn: 0.5401093	total: 11.1s	remaining: 4.16s
# 218:	learn: 0.5400269	total: 11.1s	remaining: 4.11s
# 219:	learn: 0.5399765	total: 11.2s	remaining: 4.06s
# 220:	learn: 0.5399054	total: 11.2s	remaining: 4.01s
# 221:	learn: 0.5398441	total: 11.3s	remaining: 3.96s
# 222:	learn: 0.5397533	total: 11.3s	remaining: 3.91s
# 223:	learn: 0.5396549	total: 11.4s	remaining: 3.85s
# 224:	learn: 0.5395691	total: 11.4s	remaining: 3.81s
# 225:	learn: 0.5395424	total: 11.5s	remaining: 3.75s
# 226:	learn: 0.5394895	total: 11.5s	remaining: 3.7s
# 227:	learn: 0.5394521	total: 11.6s	remaining: 3.65s
# 228:	learn: 0.5393942	total: 11.6s	remaining: 3.6s
# 229:	learn: 0.5392992	total: 11.6s	remaining: 3.54s
# 230:	learn: 0.5392340	total: 11.7s	remaining: 3.49s
# 231:	learn: 0.5391864	total: 11.7s	remaining: 3.44s
# 232:	learn: 0.5391333	total: 11.8s	remaining: 3.39s
# 233:	learn: 0.5390515	total: 11.8s	remaining: 3.34s
# 234:	learn: 0.5389920	total: 11.9s	remaining: 3.29s
# 235:	learn: 0.5389172	total: 11.9s	remaining: 3.24s
# 236:	learn: 0.5388484	total: 12s	remaining: 3.19s
# 237:	learn: 0.5388016	total: 12s	remaining: 3.13s
# 238:	learn: 0.5387494	total: 12.1s	remaining: 3.08s
# 239:	learn: 0.5386770	total: 12.1s	remaining: 3.03s
# 240:	learn: 0.5386083	total: 12.2s	remaining: 2.98s
# 241:	learn: 0.5385684	total: 12.2s	remaining: 2.93s
# 242:	learn: 0.5385232	total: 12.3s	remaining: 2.87s
# 243:	learn: 0.5384528	total: 12.3s	remaining: 2.83s
# 244:	learn: 0.5383999	total: 12.3s	remaining: 2.77s
# 245:	learn: 0.5383472	total: 12.4s	remaining: 2.72s
# 246:	learn: 0.5382776	total: 12.4s	remaining: 2.67s
# 247:	learn: 0.5382203	total: 12.5s	remaining: 2.62s
# 248:	learn: 0.5381904	total: 12.5s	remaining: 2.57s
# 249:	learn: 0.5381341	total: 12.6s	remaining: 2.52s
# 250:	learn: 0.5380299	total: 12.6s	remaining: 2.47s
# 251:	learn: 0.5379701	total: 12.7s	remaining: 2.42s
# 252:	learn: 0.5379035	total: 12.7s	remaining: 2.37s
# 253:	learn: 0.5378540	total: 12.8s	remaining: 2.31s
# 254:	learn: 0.5377944	total: 12.8s	remaining: 2.26s
# 255:	learn: 0.5377400	total: 12.9s	remaining: 2.21s
# 256:	learn: 0.5376950	total: 12.9s	remaining: 2.16s
# 257:	learn: 0.5376232	total: 13s	remaining: 2.11s
# 258:	learn: 0.5375497	total: 13s	remaining: 2.06s
# 259:	learn: 0.5375221	total: 13.1s	remaining: 2.01s
# 260:	learn: 0.5374577	total: 13.1s	remaining: 1.96s
# 261:	learn: 0.5374022	total: 13.2s	remaining: 1.91s
# 262:	learn: 0.5373566	total: 13.2s	remaining: 1.86s
# 263:	learn: 0.5372817	total: 13.3s	remaining: 1.81s
# 264:	learn: 0.5372257	total: 13.3s	remaining: 1.76s
# 265:	learn: 0.5371657	total: 13.4s	remaining: 1.71s
# 266:	learn: 0.5371190	total: 13.4s	remaining: 1.66s
# 267:	learn: 0.5370477	total: 13.5s	remaining: 1.61s
# 268:	learn: 0.5369896	total: 13.5s	remaining: 1.56s
# 269:	learn: 0.5369555	total: 13.5s	remaining: 1.5s
# 270:	learn: 0.5369007	total: 13.6s	remaining: 1.45s
# 271:	learn: 0.5368716	total: 13.6s	remaining: 1.4s
# 272:	learn: 0.5368295	total: 13.7s	remaining: 1.35s
# 273:	learn: 0.5367926	total: 13.7s	remaining: 1.3s
# 274:	learn: 0.5367489	total: 13.8s	remaining: 1.25s
# 275:	learn: 0.5366790	total: 13.8s	remaining: 1.2s
# 276:	learn: 0.5366529	total: 13.9s	remaining: 1.15s
# 277:	learn: 0.5365866	total: 13.9s	remaining: 1.1s
# 278:	learn: 0.5365475	total: 14s	remaining: 1.05s
# 279:	learn: 0.5365095	total: 14s	remaining: 1000ms
# 280:	learn: 0.5364559	total: 14s	remaining: 949ms
# 281:	learn: 0.5364178	total: 14.1s	remaining: 899ms
# 282:	learn: 0.5363741	total: 14.1s	remaining: 849ms
# 283:	learn: 0.5363275	total: 14.2s	remaining: 799ms
# 284:	learn: 0.5362939	total: 14.2s	remaining: 748ms
# 285:	learn: 0.5362409	total: 14.3s	remaining: 699ms
# 286:	learn: 0.5362137	total: 14.3s	remaining: 650ms
# 287:	learn: 0.5361704	total: 14.4s	remaining: 600ms
# 288:	learn: 0.5361242	total: 14.5s	remaining: 551ms
# 289:	learn: 0.5360712	total: 14.5s	remaining: 501ms
# 290:	learn: 0.5360347	total: 14.6s	remaining: 451ms
# 291:	learn: 0.5359742	total: 14.6s	remaining: 401ms
# 292:	learn: 0.5359315	total: 14.7s	remaining: 351ms
# 293:	learn: 0.5358990	total: 14.7s	remaining: 301ms
# 294:	learn: 0.5358568	total: 14.8s	remaining: 251ms
# 295:	learn: 0.5358182	total: 14.8s	remaining: 200ms
# 296:	learn: 0.5357905	total: 14.9s	remaining: 150ms
# 297:	learn: 0.5357429	total: 14.9s	remaining: 100ms
# 298:	learn: 0.5356963	total: 15s	remaining: 50.1ms
# 299:	learn: 0.5356418	total: 15s	remaining: 0us
# 0.41791997164724065

# %%
CatB_feature_imp = pd.DataFrame(sorted(zip(CatB.feature_importances_,X.columns)), columns=['Value','Feature'])

fig,ax = plt.subplots(1,1,figsize=(20,30))
sns.barplot(x="Value", y="Feature", data=CatB_feature_imp.sort_values(by="Value", ascending=False), ax=ax)
plt.title('CatBoostRegressorr Features Importance')
# Out:
# Text(0.5, 1.0, 'CatBoostRegressorr Features Importance')

# %%
test_predictions3 = CatB.predict(test_data)

predictions3=np.exp(test_predictions3)-1
sample_submission3['loss']=predictions3


CatBResult = sample_submission3.loc[:, ['id','loss']]

CatBResult.to_csv('Result3.csv', index=False)
CatBResult.head()
# Out:
#    id         loss
# 0   4  1531.511274
# 1   6  1705.619789
# 2   9  9051.938984
# 3  12  6235.852838
# 4  15   892.652024
